# %% [markdown]
# # Setup and Context

# %% [markdown]
# ### Introduction
#
# On November 27, 1895, Alfred Nobel signed his last will in Paris. When it was opened after his death, the will caused a lot of controversy, as Nobel had left much of his wealth for the establishment of a prize.
#
# Alfred Nobel dictates that his entire remaining estate should be used to endow “prizes to those who, during the preceding year, have conferred the greatest benefit to humankind”.
#
# Every year the Nobel Prize is given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace.
#
# <img src=https://i.imgur.com/36pCx5Q.jpg>
#
# This data is not suitable for creating RAG Application we have to do some process on it. So we done data cleaning on it before.

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Read the Data

# %%
df_data = pd.read_csv('/content/nobel_prize_data.csv')

# %% [markdown]
# # Data Cleaning
#
# * What is the shape of `df_data`? How many rows and columns?
# * What are the column names?

# %%
df_data.shape
# Out:
# (1001, 16)

# %%
df_data.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...       1-Jan
# 1  "in special recognition of his poetic composit...       1-Jan
# 2  "for his work on serum therapy, especially its...       1-Jan
# 3                                                NaN       2-Jan
# 4                                                NaN       2-Jan
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual                Frédéric Passy  1822-05-20              Paris
# 4    Individual             Jean Henry Dunant  1828-05-08             Geneva
#
#       birth_country birth_country_current   sex   organization_name  \
# 0       Netherlands           Netherlands  Male   Berlin University
# 1            France                France  Male                 NaN
# 2  Prussia (Poland)                Poland  Male  Marburg University
# 3            France                France  Male                 NaN
# 4       Switzerland           Switzerland  Male                 NaN
#
#   organization_city organization_country  ISO
# 0            Berlin              Germany  NLD
# 1               NaN                  NaN  FRA
# 2           Marburg              Germany  POL
# 3               NaN                  NaN  FRA
# 4               NaN                  NaN  CHE

# %%
df_data.tail()
# Out:
#       year    category                                           prize  \
# 996   1929       Peace                      The Nobel Peace Prize 1929
# 997   1929     Physics                 The Nobel Prize in Physics 1929
# 998   1930   Chemistry               The Nobel Prize in Chemistry 1930
# 999   1930  Literature              The Nobel Prize in Literature 1930
# 1000  1930    Medicine  The Nobel Prize in Physiology or Medicine 1930
#
#                                              motivation prize_share  \
# 996                                                 NaN       1-Jan
# 997   "for his discovery of the wave nature of elect...       1-Jan
# 998   "for his researches into the constitution of h...       1-Jan
# 999   "for his vigorous and graphic art of descripti...       1-Jan
# 1000          "for his discovery of human blood groups"       1-Jan
#
#      laureate_type                                      full_name  birth_date  \
# 996     Individual                         Frank Billings Kellogg  1856-12-22
# 997     Individual  Prince Louis-Victor Pierre Raymond de Broglie  1892-08-15
# 998     Individual                                   Hans Fischer  1881-07-27
# 999     Individual                                 Sinclair Lewis  1885-02-07
# 1000    Individual                               Karl Landsteiner  1868-06-14
#
#            birth_city              birth_country     birth_country_current  \
# 996       Potsdam, NY   United States of America  United States of America
# 997            Dieppe                     France                    France
# 998           Hoechst                    Germany                   Germany
# 999   Sauk Centre, MN   United States of America  United States of America
# 1000           Vienna  Austrian Empire (Austria)                   Austria
#
#        sex                                organization_name organization_city  \
# 996   Male                                              NaN               NaN
# 997   Male                              Sorbonne University             Paris
# 998   Male  Technische Hochschule (Institute of Technology)            Munich
# 999   Male                                              NaN               NaN
# 1000  Male       Rockefeller Institute for Medical Research      New York, NY
#
#           organization_country  ISO
# 996                        NaN  USA
# 997                     France  FRA
# 998                    Germany  DEU
# 999                        NaN  USA
# 1000  United States of America  AUT

# %%
df_data.columns
# Out:
# Index(['year', 'category', 'prize', 'motivation', 'prize_share',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'birth_country_current', 'sex', 'organization_name',
#        'organization_city', 'organization_country', 'ISO'],
#       dtype='object')

# %% [markdown]
# ###Drop Useless Columns

# %%
df_data.drop(columns=['ISO', 'prize_share'], inplace=True)

# %% [markdown]
# ### Check for Duplicates

# %%
df_data.duplicated().sum()
# Out:
# np.int64(39)

# %% [markdown]
# ###Remove Duplicates

# %%
df_data.drop_duplicates(inplace=True)

# %% [markdown]
# ##Check if df_data still has duplicates after removing Duplicated rows

# %%
df_data.duplicated().values.any()
# Out:
# np.False_

# %% [markdown]
# ### Check for NaN Values

# %%
df_data.isna().values.any()
# Out:
# np.True_

# %%
df_data.isna().sum()
# Out:
# year                       0
# category                   0
# prize                      0
# motivation                88
# laureate_type              0
# full_name                  0
# birth_date                28
# birth_city                31
# birth_country             28
# birth_country_current     28
# sex                       28
# organization_name        255
# organization_city        255
# organization_country     254
# dtype: int64

# %% [markdown]
# ###Fill missing values and delete critical row

# %%
sub_column = [
    "motivation", "birth_city", "birth_country",
    "birth_country_current", "organization_name", "birth_date",
    "organization_city", "organization_country","sex"
]

df_data[sub_column] = df_data[sub_column].fillna("")

# %%
df_data["sex"] = df_data["sex"].replace({"": "unknown"})
df_data["laureate_type"] = df_data["laureate_type"].replace("", "individual")

# %% [markdown]
# ##Check the NULL values after fixing

# %%
df_data.isna().sum()
# Out:
# year                     0
# category                 0
# prize                    0
# motivation               0
# laureate_type            0
# full_name                0
# birth_date               0
# birth_city               0
# birth_country            0
# birth_country_current    0
# sex                      0
# organization_name        0
# organization_city        0
# organization_country     0
# dtype: int64

# %% [markdown]
# ### Type Conversions

# %% [markdown]
# #### Convert Year to int and Birth Date to Datetime

# %%
df_data["year"] = df_data["year"].astype(int)

# %%
df_data.birth_date = pd.to_datetime(df_data.birth_date, format="mixed")

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 962 entries, 0 to 961
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   962 non-null    int64
#  1   category               962 non-null    object
#  2   prize                  962 non-null    object
#  3   motivation             962 non-null    object
#  4   laureate_type          962 non-null    object
#  5   full_name              962 non-null    object
#  6   birth_date             934 non-null    datetime64[ns]
#  7   birth_city             962 non-null    object
#  8   birth_country          962 non-null    object
#  9   birth_country_current  962 non-null    object
#  10  sex                    962 non-null    object
#  11  organization_name      962 non-null    object
#  12  organization_city      962 non-null    object
#  13  organization_country   962 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 112.7+ KB

# %% [markdown]
# ###Describe data_frame after cleaning

# %%
df_data.shape
# Out:
# (962, 14)

# %% [markdown]
# ###Save the cleaned File for RAG Implementation

# %%
df_data.to_csv('cleaned_nobel_prize_data.csv', index=False)
